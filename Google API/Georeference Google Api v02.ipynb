# %%
# Dependencies
import requests
import json
import pandas as pd

# Google developer API key
gkey="Pon aqui tu API key"

# %%
addresses = pd.read_csv('Rentas_vpc.csv', encoding="utf-8-sig")
display(addresses.head())
display(addresses.count())
# Out:
#                                          name  \
# 0                 City Rent - Parques Polanco
# 1      Nomad Santa Fe, Departamentos en Renta
# 2       Nomad Mítikah, Departamentos en Renta
# 3                                Niu Coliving
# 4  Nomad Lago Alberto, Departamentos en Renta
#
#                                             location  \
# 0              Lago Mayor 6, Polanco, Miguel Hidalgo
# 1         Av. Santa Fe 578, Santa Fe, Alvaro Obregón
# 2       Av. Río Churubusco 601, Del Carmen, Coyoacán
# 3  Monte Alban- Entre Torres  Adalid y Concepción...
# 4          Lago Alberto 369, Polanco, Miguel Hidalgo
#
#                                          description  \
# 0  "All Inclusive Lifestyle" En City Rent creamos...
# 1  Renta tu próximo depa desde la comodidad de tu...
# 2  Renta tu próximo depa desde la comodidad de tu...
# 3  Gracias por querer formar parte de nuestra com...
# 4  Renta tu próximo depa desde la comodidad de tu...
#
#                                                 link      price operation  \
# 0  /propiedades/city-rent-parques-polanco-5355970...  MN 14,900     renta
# 1  /propiedades/nomad-santa-fe-departamentos-en-r...  MN 16,500     renta
# 2  /propiedades/nomad-mitikah-departamentos-en-re...  MN 14,800     renta
# 3            /propiedades/niu-coliving-57761914.html  MN 14,200     renta
# 4  /propiedades/nomad-lago-alberto-departamentos-...  MN 16,600     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad  \
# 0    2.0        0.0               92.0          98.0  Departamento    CDMX
# 1    1.5        0.0                0.0           0.0  Departamento    CDMX
# 2    1.5        0.0                0.0           0.0  Departamento    CDMX
# 3    1.0        0.0               45.0          45.0  Departamento    CDMX
# 4    1.5        0.0               50.0          50.0  Departamento    CDMX
#
#   Moneda   Monto Iniciales
# 0     MN  14,900       VPC
# 1     MN  16,500       VPC
# 2     MN  14,800       VPC
# 3     MN  14,200       VPC
# 4     MN  16,600       VPC
# name                 5580
# location             5580
# description          5580
# link                 5580
# price                5580
# operation            5580
# rooms                5580
# bathrooms            5580
# construction (m2)    5580
# terrain (m2)         5580
# propiedad            5580
# entidad              5580
# Moneda               5580
# Monto                5580
# Iniciales            5580
# dtype: int64

# %%
#input the address
addressinput = addresses["location"].tolist()
print(addressinput)
# Out:
# ['Lago Mayor 6, Polanco, Miguel Hidalgo', 'Av. Santa Fe 578, Santa Fe, Alvaro Obregón', 'Av. Río Churubusco 601, Del Carmen, Coyoacán', 'Monte Alban- Entre Torres  Adalid y Concepción B, Narvarte, Benito Juárez', 'Lago Alberto 369, Polanco, Miguel Hidalgo', 'Arquimedes 189, Polanco, Miguel Hidalgo', 'Lago Mayor, Granada, Miguel Hidalgo', 'Emerson, Lido Residences Departamento Nuevo en Renta, Polanco, Polanco IV Sección, Miguel Hidalgo', 'Ped
Rio Rhin, Cuauhtémoc, Cuauhtémoc', 'Cabrio, Lomas de San Angel Inn, Alvaro Obregón', 'San Felipe, Miguel Hidalgo, Tlalpan', 'Petén, Vertiz Narvarte, Benito Juárez', 'SUDERMANN, Polanco, Miguel Hidalgo', 'Rio Amazonas 48, Cuauhtémoc, Cuauhtémoc', 'Puebla 272, Condesa, Cuauhtémoc', 'Calle Arquímedes, Polanco, Miguel Hidalgo', 'Sinaloa, Roma Norte, Cuauhtémoc', 'Poniente 113-A, Granada, Miguel Hidalgo', 'callejón general analla, San Diego Churubusco, Coyoacán', 'Roma, Cuauhtémoc', 'Santa Fe La Loma, Alvaro Obregón', 'PRESA FALCON 219, Polanco, Miguel Hidalgo', 'Hamburgo, Juárez, Cuauhtémoc', 'Reforma, Barrio Santa Catarina, Coyoacán', 'Blvd. Adolfo Ruiz Cortines, Pedregal de Carrasco, Coyoacán', 'Av De Las Torres 800, Torres de Potrero, Alvaro Obregón', 'Bernardo Quintana, Santa Fe La Loma, Alvaro Obregón', 'Callejón General Anaya, San Diego Churubusco, Coyoacán', 'Carretera a san Francisco Tlalnepantla, Villa Xochimilco, Xochimilco', 'Eugenia 302, Del Valle, Benito Juárez', 'Av. Prolongación San Antonio, Carola, Alvaro Obregón', 'Calle Niño Jesús, La Joya, Tlalpan', 'Lago Zurich 272, Polanco, Miguel Hidalgo', 'Comercio, Escandón ...

# %%
# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

params = {"address": addressinput, "key": gkey}

#loop to get all locations from locaitions

lat      =[]
lng      =[]
calle    =[]
numero   =[]
colonia  =[]
ciudad   =[]
estado   =[]
CP       =[]
formatad =[]
locfound =[] #locations found
notfound =[] #locations not found

for index in params["address"]:
    #make request and print url
    try:
        response = requests.get(base_url, params={"address":index,"key": gkey})
        geo      = response.json()
        
        lat.append(geo["results"][0]["geometry"]["location"]["lat"])
        lng.append(geo["results"][0]["geometry"]["location"]["lng"])
        
        #sacar el número
        j=0
        bandera=0
        for results in geo["results"][0]["address_components"]:
            if geo["results"][0]["address_components"][j]["types"][0]=="street_number":
                numero.append(geo["results"][0]["address_components"][j]["long_name"])
                #print(f"{j} opción")
                #print(numero)
                bandera=1
            if j==len(geo["results"][0]["address_components"])-1 and bandera==0:
                numero.append(None)
                #print("noencontrado")
            j=j+1
        
        #sacar la calle
        j=0
        bandera=0
        for results in geo["results"][0]["address_components"]:
            if geo["results"][0]["address_components"][j]["types"][0]=="route":
                calle.append(geo["results"][0]["address_components"][j]["long_name"])
                #print(f"{j} opción")
                #print(calle)
                bandera=1
            if j==len(geo["results"][0]["address_components"])-1 and bandera==0:
                calle.append(None)
                #print("noencontrado")
            j=j+1
              
        #sacar la colonia
        j=0
        bandera=0
        for results in geo["results"][0]["address_components"]:
            if geo["results"][0]["address_components"][j]["types"][0]=="political" and geo["results"][0]["address_components"][j]["types"][1]=="sublocality":
                colonia.append(geo["results"][0]["address_components"][j]["long_name"])
                #print(f"{j} opción")
                #print(colonia)
                bandera=1
            if j==len(geo["results"][0]["address_components"])-1 and bandera==0:
                colonia.append(None)
                #print("noencontrado")
            j=j+1
                
        #sacar ciudad
        j=0
        bandera=0
        for results in geo["results"][0]["address_components"]:
            if geo["results"][0]["address_components"][j]["types"][0]=="locality" and geo["results"][0]["address_components"][j]["types"][1]=="political":
                ciudad.append(geo["results"][0]["address_components"][j]["long_name"])
                #print(f"{j} opción")
                #print(ciudad)
                bandera=1
            if j==len(geo["results"][0]["address_components"])-1 and bandera==0:
                ciudad.append(None)
                #print("noencontrado")
            j=j+1
                
        #Sacar Código Postal
        j=0
        bandera=0
        for results in geo["results"][0]["address_components"]:
            if geo["results"][0]["address_components"][j]["types"][0]=="postal_code" :
                CP.append(geo["results"][0]["address_components"][j]["long_name"])
                #print(f"{j} opción")
                #print(CP)
                bandera=1
            if j==len(geo["results"][0]["address_components"])-1 and bandera==0:
                CP.append(None)
                #print("noencontrado")
            j=j+1
              
        formatad.append(geo["results"][0]["formatted_address"])
        locfound.append(index)        
           
    
    except (KeyError, IndexError):
        notfound.append(index)

# %%
googleapirentacdmx = pd.DataFrame({
    'lat'      : lat,
    'lng'      : lng,
    'calle'    : calle,
    'numero'   : numero,
    'colonia'  : colonia,
    'ciudad'   : ciudad,
    #'estado'   : estado,
    'CP'       : CP,
    'formatad' : formatad,
    'location' : locfound
})
googleapirentacdmx
# Out:
#          lat        lng                                      calle numero  \
# 0  19.304019 -99.172601                                       None   None
# 1  19.435634 -99.149511                                       None   None
# 2  19.387203 -99.195097                                       None   None
# 3  19.339229 -99.218984                                       None   None
# 4  19.454661 -99.175218                                Mar de Java     26
# 5  19.365098 -99.175187                         José María Olloqui   None
# 6  19.451691 -99.219958  Periférico Boulevard Manuel Ávila Camacho   None
#
#                   colonia            ciudad     CP  \
# 0    Pedregal de Carrasco  Ciudad de México   None
# 1                    None       Mexico City   None
# 2  San Pedro de los Pinos  Ciudad de México   None
# 3    Olivar de los Padres  Ciudad de México  01780
# 4                Nextitla  Ciudad de México  11420
# 5                 Acacias  Ciudad de México   None
# 6                    None              None   None
#
#                                             formatad  \
# 0  Pedregal de Carrasco, Ciudad de México, CDMX, ...
# 1              Cuauhtémoc, Mexico City, CDMX, Mexico
# 2  San Pedro de los Pinos, Ciudad de México, CDMX...
# 3  Olivar de los Padres, 01780 Ciudad de México, ...
# 4  Mar de Java 26, Nextitla, Miguel Hidalgo, 1142...
# 5  José María Olloqui, Acacias, Ciudad de México,...
# 6  Perif. Blvd. Manuel Ávila Camacho, Cd. de Méxi...
#
#                                             location
# 0                     Pedregal de Carrasco, Coyoacán
# 1                             Cuauhtémoc, Cuauhtémoc
# 2             San Pedro de los Pinos, Alvaro Obregón
# 3               Olivar de los Padres, Alvaro Obregón
# 4            MAR DE JAVA 26, Popotla, Miguel Hidalgo
# 5                    OLLOQUI, Acacias, Benito Juárez
# 6  av manuel avila camacho , Periodista, Miguel H...

# %%
display(len(lat))
display(len(lat))   
display(len(lng))   
display(len(calle))  
display(len(numero)) 
display(len(colonia))
display(len(ciudad))
#display(len(estado))
display(len(CP))
display(len(formatad))
display(len(locfound))
display(len(notfound))
# Out:
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
#
Miguel Bernal, Torres Lindavista, Gustavo A. Madero', 'Ocaso 27, Insurgentes Cuicuilco, Coyoacán', 'Lago Zurich 219, Ampliación Granada, Miguel Hidalgo', 'Ciceron, Polanco, Miguel Hidalgo', 'LAGO ZURICH 272, Ampliación Granada, Miguel Hidalgo', 'Bajío, Roma, Cuauhtémoc', 'Antiguo Camino a Xochimilco, Villa Xochimilco, Xochimilco', 'Teotihuacan, Hipódromo, Cuauhtémoc', 'PENINSULA SANTA FE, Santa Fe, Alvaro Obregón', 'Av de los Poetas 100, San Mateo Tlaltenango, Cuajimalpa de Morelos', 'Jalapa, Roma, Cuauhtémoc', 'José Luis Lagrange, Polanco, Miguel Hidalgo', 'arquímedes, Polanco IV Sección, Miguel Hidalgo', 'Lomas de Chapultepec, Miguel Hidalgo', 'BERNARDO QUINTANA 400, Santa Fe La Loma, Alvaro Obregón', 'Rio Rhin, Cuauhtémoc, Cuauhtémoc', 'Cabrio, Lomas de San Angel Inn, Alvaro Obregón', 'San Felipe, Miguel Hidalgo, Tlalpan', 'Petén, Vertiz Narvarte, Benito Juárez', 'SUDERMANN, Polanco, Miguel Hidalgo', 'Rio Amazonas 48, Cuauhtémoc, Cuauhtémoc', 'Puebla 272, Condesa, Cuauhtémoc', 'Calle Arquímedes, Polanco, Miguel Hidalgo', 'Sinaloa, Roma Norte, Cuauhtémoc', 'Poniente 113-A, Granada, Miguel Hidalgo', 'callejón general analla, San Diego Churubusco, Coyoacán', 'Roma, Cuauhtémoc', 'Santa Fe La Loma, Alvaro Obregón', 'PRESA FALCON 219, Polanco, Miguel Hidalgo', 'Hamburgo, Juárez, Cuauhtémoc', 'Reforma, Barrio Santa Catarina, Coyoacán', 'Blvd. Adolfo Ruiz Cortines, Pedregal de Carrasco, Coyoacán', 'Av De Las Torres 800, Torres de Potrero, Alvaro Obregón', 'Bernardo Quintana, Santa Fe La Loma, Alvaro Obregón', 'Callejón General Anaya, San Diego Churubusco, Coyoacán', 'Carretera a san Francisco Tlalnepantla, Villa Xochimilco, Xochimilco', 'Eugenia 302, Del Valle, Benito Juárez', 'Av. Prolongación San Antonio, Carola, Alvaro Obregón', 'Calle Niño Jesús, La Joya, Tlalpan', 'Lago Zurich 272, Polanco, Miguel Hidalgo', 'Comercio, Escandón, Miguel Hidalgo', 'Avenida Henry  ...

# %%
 # Print the json (pretty printed)
#print(json.dumps(geo, indent=4, sort_keys=True))
# Out:
#      Unnamed: 0                                               name  \
# 0             0                 Sierra Gorda, Lomas de Chapultepec
# 1             1          Enquentro Residencial Insurgentes Mixcoac
# 2             2                               Sky Tower Lindavista
# 3             3                                         Musset 326
# 4             4                                        Progreso 40
# ..          ...                                                ...
# 995         995  Departamento en Venta o Renta en Be Grand Cont...
# 996         996                Departamento - San José Insurgentes
# 997         997  Cad Punta del Parque Santa Fe Tb Ph1 2 Niveles...
# 998         998                 Casa en Venta Lomas de Chapultepec
# 999         999                    Oficina - Barrio Santa Catarina
#
#                                               location  \
# 0    Calle Sierra gorda, Lomas de Chapultepec, Migu...
# 1    Patriotismo 883, Insurgentes Mixcoac, Benito J...
# 2    Av. Insurgentes Norte. 1346, Lindavista,  Ciud...
# 3          Alfredo Musset 326, Polanco, Miguel Hidalgo
# 4                PROGRESO 40, Escandón, Miguel Hidalgo
# ..                                                 ...
# 995  CARRETERA MÉXICO-TOLUCA, Contadero, Cuajimalpa...
# 996  SAN Jose Insurgentes, San José Insurgentes, Be...
# 997  Colonia Santa Fe Cuajimalpa, Santa Fe Cuajimal...
# 998  MONTE CHIMBORAZO, Lomas de Chapultepec, Miguel...
# 999        Tata Vasco, Barrio Santa Catarina, Coyoacán
#
#                                            description  \
# 0    La exclusiva zona residencial de Lomas de Chap...
# 1    Enquentro un proyecto moderno y singular. Ven ...
# 2    Sky tower lindavista es un desarrollo de 184 d...
# 3    Atractivo e innovador proyecto residencial en ...
# 4    Super oportunidad, aprovecha un 8% de descuent...
# ..                                                 ...
# 995  Excelente Oportunidad. Precioso departamento t...
# 996  PentHouse en San Jose Insurgentes, sobre Barra...
# 997  Cad Punta del Parque Santa Fe. Torre B Pent Ho...
# 998  Terreno regular. Con grande y Precioso jardín....
# 999  Excelente propiedad para oficinas en Coyoacán ...
#
#                                                   link          price  \
# 0    /propiedades/sierra-gorda-lomas-de-chapultepec...  MN 25,000,000
# 1    /propiedades/enquentro-residencial-insurgentes...   MN 5,523,587
# 2      /propiedades/sky-tower-lindavista-54456938.html   MN 3,210,000
# 3                /propiedades/musset-326-56045986.html  MN 20,098,744
# 4               /propiedades/progreso-40-57552849.html   MN 4,488,000
# ..                                                 ...            ...
# 995  /propiedades/departamento-en-venta-o-renta-en-...   MN 5,700,000
# 996  /propiedades/departamento-san-jose-insurgentes...  MN 26,999,000
# 997  /propiedades/cad-punta-del-parque-santa-fe-tb-...  USD 1,620,000
# 998  /propiedades/casa-en-venta-lomas-de-chapultepe...  USD 2,150,000
# 999  /propiedades/oficina-barrio-santa-catarina-572...  MN 27,500,000
#
#     operation  rooms  bathrooms  construction (m2)  terrain (m2)
# 0       venta    2.5        NaN              282.0         416.5
# 1       venta    2.5        NaN              140.5         140.5
# 2       venta    2.0        NaN               79.5         122.0
# 3       venta    2.5        NaN              294.0         328.0
# 4       venta    2.0        NaN              114.0         161.0
# ..        ...    ...        ...                ...           ...
# 995     venta    2.0        2.0               97.0          97.0
# 996     venta    3.0        3.0              363.0         363.0
# 997     venta    3.0        3.0              560.0         560.0
# 998     venta    3.0        2.0              350.0         875.0
# 999     venta    NaN        6.0              664.0         645.0
#
# [1000 rows x 11 columns]

# %%
googleapivtacdmx.to_csv("resultado_google_api.csv",encoding="utf-8-sig",index=False)

# %%
jointinfo_df = pd.merge(addresses, googleapivtacdmx, on="location" , how="inner")
#jointinfo_df.set_index("location")
jointinfo_df.drop_duplicates(subset=['name', 'location', 'description', 'link', 'price', 'operation',
       'rooms', 'bathrooms', 'construction (m2)', 'terrain (m2)', 'propiedad',
       'entidad', 'Moneda', 'Monto', 'Iniciales', 'lat', 'lng', 'calle',
       'numero', 'colonia', 'ciudad', 'CP', 'formatad'], keep="first", inplace=True)
jointinfo_df
# Out:
#                                                     name  \
# 0      Estrena Bgrand Alto Pedregal, Junto Al Colegio...
# 1      Bonito Departamento en Renta Sin Muebles en Hi...
# 2       Departamento en Renta en High Park Sur, Coyoacán
# 3      Precioso Departamento Al Sur en High Park Resi...
# 4              Departamento Nuevo en Renta High Park Sur
# ...                                                  ...
# 20398                        Depto. en Renta en Polanco.
# 20400                         Cerca de Portal Churubusco
# 20401     Departamento en Renta en Bosques de Tabachines
# 20402  Se Renta a Estrenar Cómodo Penthouse en Narvar...
# 20403  Depto. Seminuevo en Venta y Renta en Santa Fe ...
#
#                                                 location  \
# 0                         Pedregal de Carrasco, Coyoacán
# 1                         Pedregal de Carrasco, Coyoacán
# 2                         Pedregal de Carrasco, Coyoacán
# 3                         Pedregal de Carrasco, Coyoacán
# 4                         Pedregal de Carrasco, Coyoacán
# ...                                                  ...
# 20398                  Petrarca, Polanco, Miguel Hidalgo
# 20400                              El Retoño, Iztapalapa
# 20401  Bosques de Tabachines, Bosques de las Lomas, C...
# 20402                La Quemada, Narvarte, Benito Juárez
# 20403  Guillermo Gonzalez Camarena, Santa Fe, Alvaro ...
#
#                                              description  \
# 0      Periférico Sur 5146 Pedregal de Carrasco, Coyo...
# 1      Lujoso departamento en renta con acabados de b...
# 2      Estrena departamento en High Park Sur. Nuevo í...
# 3      Espectacular departamento a estrenar, amplio y...
# 4      Departamento con acabados de lujo, una bodega....
# ...                                                  ...
# 20398  Acogedor departamento en Renta en Polanco. May...
# 20400  Departamento de 80m2 sobre Calz. La Viga, cuen...
# 20401  Espectacular departamento de 650 M2 en dos niv...
# 20402  Se renta a estrenar cómodo Penthouse en Narvar...
# 20403  Excelente depto. Semi-nuevo muy bien ubicado e...
#
#                                                     link       price  \
# 0      /propiedades/estrena-bgrand-alto-pedregal-junt...   MN 24,900
# 1      /propiedades/bonito-departamento-en-renta-sin-...   MN 25,000
# 2      /propiedades/departamento-en-renta-en-high-par...   MN 18,000
# 3      /propiedades/precioso-departamento-al-sur-en-h...   MN 31,000
# 4      /propiedades/departamento-nuevo-en-renta-high-...   MN 19,900
# ...                                                  ...         ...
# 20398  /propiedades/depto.-en-renta-en-polanco.-57078...   USD 3,000
# 20400  /propiedades/cerca-de-portal-churubusco-566410...   MN 12,500
# 20401  /propiedades/departamento-en-renta-en-bosques-...  MN 120,000
# 20402  /propiedades/se-renta-a-estrenar-comodo-pentho...   MN 24,000
# 20403  /propiedades/depto.-seminuevo-en-venta-y-renta...   MN 24,490
#
#       operation  rooms  bathrooms  construction (m2)  terrain (m2)  ...  \
# 0         renta    3.0        3.0              130.0         130.0  ...
# 1         renta    2.0        2.0               87.0          87.0  ...
# 2         renta    2.0        2.0               90.0          90.0  ...
# 3         renta    3.0        3.0              142.0         142.0  ...
# 4         renta    2.0        2.0               87.0          87.0  ...
# ...         ...    ...        ...                ...           ...  ...
# 20398     renta    1.0        1.0               72.0          72.0  ...
# 20400     renta    2.0        2.0               80.0          80.0  ...
# 20401     renta    3.0        4.0              650.0         650.0  ...
# 20402     renta    2.0        2.0                0.0         130.0  ...
# 20403     renta    2.0        2.0              143.0         142.0  ...
#
#          Monto Iniciales        lat        lng  \
# 0       24,900       VPC  19.304019 -99.172601
# 1       25,000       VPC  19.304019 -99.172601
# 2       18,000       VPC  19.304019 -99.172601
# 3       31,000       VPC  19.304019 -99.172601
# 4       19,900       VPC  19.304019 -99.172601
# ...        ...       ...        ...        ...
# 20398    3,000       VPC  19.434213 -99.185609
# 20400   12,500       VPC  19.373440 -99.124863
# 20401  120,000       VPC  19.387193 -99.255133
# 20402   24,000       VPC  19.392473 -99.149202
# 20403   24,490       VPC  19.366602 -99.263853
#
#                                    calle  numero               colonia  \
# 0                                   None    None  Pedregal de Carrasco
# 1                                   None    None  Pedregal de Carrasco
# 2                                   None    None  Pedregal de Carrasco
# 3                                   None    None  Pedregal de Carrasco
# 4                                   None    None  Pedregal de Carrasco
# ...                                  ...     ...                   ...
# 20398                           Petrarca    None     Polanco V Sección
# 20400                               None    None             El Retoño
# 20401               Bosque de Tabachines    None  Bosques de las Lomas
# 20402                         La Quemada    None                  None
# 20403  Calle Guillermo Gonzalez Camarena    None        Zedec Santa Fé
#
#                  ciudad     CP  \
# 0      Ciudad de México   None
# 1      Ciudad de México   None
# 2      Ciudad de México   None
# 3      Ciudad de México   None
# 4      Ciudad de México   None
# ...                 ...    ...
# 20398  Ciudad de México  11560
# 20400  Ciudad de México  09440
# 20401  Ciudad de México   None
# 20402  Ciudad de México   None
# 20403  Ciudad de México  01219
#
#                                                 formatad
# 0      Pedregal de Carrasco, Ciudad de México, CDMX, ...
# 1      Pedregal de Carrasco, Ciudad de México, CDMX, ...
# 2      Pedregal de Carrasco, Ciudad de México, CDMX, ...
# 3      Pedregal de Carrasco, Ciudad de México, CDMX, ...
# 4      Pedregal de Carrasco, Ciudad de México, CDMX, ...
# ...                                                  ...
# 20398  Petrarca, Chapultepec Morales, Polanco V Secc,...
# 20400    El Retoño, 09440 Ciudad de México, CDMX, Mexico
# 20401  Bosque de Tabachines, Bosques de las Lomas, Ci...
# 20402         La Quemada, Ciudad de México, CDMX, Mexico
# 20403  Calle Guillermo Gonzalez Camarena, Santa Fe, Z...
#
# [1612 rows x 23 columns]

# %%
jointinfo_df.to_csv("Renta_google_vpc.csv",encoding="utf-8-sig",index=False)
